# %% [markdown]
# **Why do you need a separate notebook for installation?**<br>
# When you open a notebook you are in the end submitting a job, so you cannot install packages for the loaded and use them "on the fly" in the same interactive session.<br>
# Once this is installed, you may close installation notebook, and when you open another notebook with the same module, installed libraries should work.

# %%
! pip3 install --upgrade pip
# Out:
# Requirement already satisfied: pip in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (26.0.1)

# %%
! pip3 install -r requirements.txt
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Requirement already satisfied: torch in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (2.10.0)
# Requirement already satisfied: torchvision in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (0.25.0)
# Requirement already satisfied: torchaudio in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (2.10.0)
# Requirement already satisfied: numpy in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (2.4.2)
# Requirement already satisfied: pandas in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: scikit-image in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (0.26.0)
# Requirement already satisfied: scikit-learn in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (1.8.0)
# Requirement already satisfied: scipy in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (1.17.0)
# Requirement already satisfied: opencv-python in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (4.13.0.92)
# Requirement already satisfied: matplotlib in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (3.10.8)
# Requirement already satisfied: seaborn in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (0.13.2)
# Requirement already satisfied: wandb in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 13)) (0.24.2)
# Requirement already satisfied: tqdm in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 14)) (4.67.3)
# Requirement already satisfied: filelock in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 2)) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: setuptools in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 2)) (82.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 2)) (3.6.1)
# Requirement already satisfied: jinja2 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 2)) (2026.2.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 2)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 2)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 2)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 2)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 2)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 2)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 2)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 2)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 2)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 2)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 2)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 2)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 2)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 2)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 2)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 2)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from cuda-bindings==12.9.4->torch->-r requirements.txt (line 2)) (1.3.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from torchvision->-r requirements.txt (line 3)) (12.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from scikit-image->-r requirements.txt (line 7)) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from scikit-image->-r requirements.txt (line 7)) (2026.1.28)
# Requirement already satisfied: packaging>=21 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from scikit-image->-r requirements.txt (line 7)) (26.0)
# Requirement already satisfied: lazy-loader>=0.4 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from scikit-image->-r requirements.txt (line 7)) (0.4)
# Requirement already satisfied: joblib>=1.3.0 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from scikit-learn->-r requirements.txt (line 8)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from scikit-learn->-r requirements.txt (line 8)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 11)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 11)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 11)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 11)) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 11)) (3.3.2)
# Requirement already satisfied: click>=8.0.1 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from wandb->-r requirements.txt (line 13)) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from wandb->-r requirements.txt (line 13)) (3.1.46)
# Requirement already satisfied: platformdirs in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from wandb->-r requirements.txt (line 13)) (4.5.1)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from wandb->-r requirements.txt (line 13)) (6.33.5)
# Requirement already satisfied: pydantic<3 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from wandb->-r requirements.txt (line 13)) (2.12.5)
# Requirement already satisfied: pyyaml in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from wandb->-r requirements.txt (line 13)) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from wandb->-r requirements.txt (line 13)) (2.32.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from wandb->-r requirements.txt (line 13)) (2.52.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from pydantic<3->wandb->-r requirements.txt (line 13)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from pydantic<3->wandb->-r requirements.txt (line 13)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from pydantic<3->wandb->-r requirements.txt (line 13)) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb->-r requirements.txt (line 13)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb->-r requirements.txt (line 13)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb->-r requirements.txt (line 13)) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb->-r requirements.txt (line 13)) (2026.1.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 13)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 13)) (5.0.2)
# Requirement already satisfied: six>=1.5 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/cristinatsak/Desktop/NNCV/.venv/lib/python3.12/site-packages (from jinja2->torch->-r requirements.txt (line 2)) (3.0.3)
